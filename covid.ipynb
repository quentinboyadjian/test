# %%
import csv
import os 
import pandas as pd
import numpy as np
from pathlib import Path 
import matplotlib as plt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter

# %%
info=pd.read_csv("/home/quentin/Documents/covid/covid19.csv", engine='python')

# %%
print(info[info["prname"]=="Quebec"])
# Out:
#      pruid  prname prnameFR        date  numconf  numprob  numdeaths  \
# 29      24  Quebec   Québec  01-03-2020        1        0        0.0
# 33      24  Quebec   Québec  03-03-2020        1        0        0.0
# 37      24  Quebec   Québec  05-03-2020        2        0        0.0
# 41      24  Quebec   Québec  06-03-2020        2        0        0.0
# 45      24  Quebec   Québec  07-03-2020        2        0        0.0
# 49      24  Quebec   Québec  08-03-2020        3        0        0.0
# 54      24  Quebec   Québec  09-03-2020        4        0        0.0
# 59      24  Quebec   Québec  11-03-2020        7        0        0.0
# 77      24  Quebec   Québec  12-03-2020       13        0        0.0
# 92      24  Quebec   Québec  13-03-2020       17        0        0.0
# 107     24  Quebec   Québec  14-03-2020       17        0        0.0
# 122     24  Quebec   Québec  15-03-2020       24        0        0.0
# 137     24  Quebec   Québec  16-03-2020       39        0        0.0
# ...

# %%
#print(info[info["prname"]=="Quebec"])
fig, axes = plt.subplots(1,2,)
axes[0].plot(info[info["prname"]=="Quebec"]["date"],info[info["prname"]=="Quebec"]["numdeaths"])
axes[1].set_yscale("log")
axes[1].plot(info[info["prname"]=="Quebec"]["date"],info[info["prname"]=="Quebec"]["numdeaths"])

# rotate and align the tick labels so they look better
fig.autofmt_xdate()

plt.show()
plt.close()
